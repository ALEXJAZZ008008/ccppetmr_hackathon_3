# %%
from __future__ import division, print_function
from tensorflow import keras as K
import numpy as np
L = K.layers
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8487d8cb7d9a> in <module>()
#       1 from __future__ import division, print_function
# ----> 2 from tensorflow import keras as K
#       3 import numpy as np
#       4 L = K.layers
#
# ImportError: No module named tensorflow

# %%
# random data for now
x_train = np.random.rand(100, 57, 57, 2)  # 100 images, shape (57, 57), channels static & moving
y_train = np.random.rand(100, 3) * 2 - 1  # 100 3-vectors

# %%
# normalisation: change dtype (speed)
x_train = x_train.astype('float32')
x_train /= x_train.std(axis=(1, 2))[:, None, None]  # ensures unit stdev

# %%
input_x = L.Input(x_train.shape[1:])

# 3 x 3 x (previous num channels = 2) kernels (32 times => 32 output channels)
# padding='same' for zero padding
x = L.Conv2D(32, 3, activation='relu', padding='same')(input_x)
x = L.Conv2D(64, 3, activation='relu', padding='same')(x) # 3 x 3 x (previous num channels = 32) kernels (64 times)
x = L.MaxPooling2D(2)(x)  # downsample by factor of 2, using "maximum" interpolation
x = L.Dropout(0.25)(x)  # discard 25% outputs
x = L.Flatten()(x)  # vectorise
x = L.Dense(128, activation='relu')(x)  # traditional neural layer with 128 outputs
x = L.Dropout(0.5)(x)
x = L.Dense(3, activation=K.activations.tanh)(x)  # 3 outputs

model = K.Model(input_x, x)
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 57, 57, 2)]       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 57, 57, 32)        608
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 57, 57, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               6422656
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 6,442,147
# Trainable params: 6,442,147
# Non-trainable params: 0
# _________________________________________________________________

# %%
# N x 3

# losses:  K.losses.*
# optimisers: K.optimizers.*
model.compile(optimizer=K.optimizers.Adam(), loss=K.losses.mean_squared_error)

model.fit(x_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 1s 6ms/sample - loss: 1.0049
# Epoch 2/100
# 100/100 [==============================] - 0s 547us/sample - loss: 1.2393
# Epoch 3/100
# 100/100 [==============================] - 0s 567us/sample - loss: 1.0649
# Epoch 4/100
# 100/100 [==============================] - 0s 537us/sample - loss: 1.2613
# Epoch 5/100
# 100/100 [==============================] - 0s 549us/sample - loss: 1.1370
# Epoch 6/100
# 100/100 [==============================] - 0s 492us/sample - loss: 1.1734
# Epoch 7/100
# 100/100 [==============================] - 0s 491us/sample - loss: 1.1837
# Epoch 8/100
# 100/100 [==============================] - 0s 516us/sample - loss: 1.2033
# Epoch 9/100
# 100/100 [==============================] - 0s 484us/sample - loss: 1.1886
# Epoch 10/100
# 100/100 [==============================] - 0s 488us/sample - loss: 1.1846
# Epoch 11/100
# 100/100 [==============================] - 0s 495us/sample - loss: 1.1885
# Epoch 12/100
# 100/100 [==============================] - 0s 536us/sample - loss: 1.1824
# Epoch 13/100
# 100/100 [==============================] - 0s 578us/sample - loss: 1.1886
# Epoch 14/100
# 100/100 [==============================] - 0s 579us/sample - loss: 1.1962
# Epoch 15/100
# 100/100 [==============================] - 0s 550us/sample - loss: 1.1887
# Epoch 16/100
# 100/100 [==============================] - 0s 568us/sample - loss: 1.1886
# Epoch 17/100
# 100/100 [==============================] - 0s 497us/sample - loss: 1.1779
# Epoch 18/100
# 100/100 [==============================] - 0s 490us/sample - loss: 1.1905
# Epoch 19/100
# 100/100 [==============================] - 0s 498us/sample - loss: 1.1886
# Epoch 20/100
# 100/100 [==============================] - 0s 507us/sample - loss: 1.1908
# Epoch 21/100
# 100/100 [==============================] - 0s 499us/sample - loss: 1.1886
# Epoch 22/100
# 100/100 [==============================] - 0s 502us/sample - loss: 1.1886
# Epoch 23/100
# 100/100 [==============================] - 0s 511us/sample - loss: 1.1886
# Epoch 24/100
# 100/100 [==============================] - 0s 492us/sample - loss: 1.1886
# Epoch 25/100
# 100/100 [==============================] - 0s 507us/sample - loss: 1.1957
# Epoch 26/100
# 100/100 [==============================] - 0s 501us/sample - loss: 1.1886
# Epoch 27/100
# 100/100 [==============================] - 0s 492us/sample - loss: 1.1886
# Epoch 28/100
# 100/100 [==============================] - 0s 493us/sample - loss: 1.1949
# Epoch 29/100
# 100/100 [==============================] - 0s 497us/sample - loss: 1.1886
# Epoch 30/100
# 100/100 [==============================] - 0s 469us/sample - loss: 1.1886
# Epoch 31/100
# 100/100 [==============================] - 0s 504us/sample - loss: 1.1886
# Epoch 32/100
# 100/100 [==============================] - 0s 456us/sample - loss: 1.1886
# Epoch 33/100
# 100/100 [==============================] - 0s 586us/sample - loss: 1.1886
# Epoch 34/100
# 100/100 [==============================] - 0s 594us/sample - loss: 1.1838
# Epoch 35/100
# 100/100 [==============================] - 0s 560us/sample - loss: 1.1886
# Epoch 36/100
# 100/100 [==============================] - 0s 473us/sample - loss: 1.1886
# Epoch 37/100
# 100/100 [==============================] - 0s 481us/sample - loss: 1.1886
# Epoch 38/100
# 100/100 [==============================] - 0s 454us/sample - loss: 1.1886
# Epoch 39/100
# 100/100 [==============================] - 0s 492us/sample - loss: 1.1881
# Epoch 40/100
# 100/100 [==============================] - 0s 497us/sample - loss: 1.1886
# Epoch 41/100
# 100/100 [==============================] - 0s 483us/sample - loss: 1.1886
# Epoch 42/100
# 100/100 [==============================] - 0s 481us/sample - loss: 1.1886
# Epoch 43/100
# 100/100 [==============================] - 0s 503us/sample - loss: 1.1778
# Epoch 44/100
# 100/100 [==============================] - 0s 514us/sample - loss: 1.1886
# Epoch 45/100
# 100/100 [==============================] - 0s 511us/sample - loss: 1.1886
# Epoch 46/100
# 100/100 [==============================] - 0s 559us/sample - loss: 1.1886
# Epoch 47/100
# 100/100 [==============================] - 0s 513us/sample - loss: 1.1881
# Epoch 48/100
# 100/100 [==============================] - 0s 606us/sample - loss: 1.1886
# Epoch 49/100
# 100/100 [==============================] - 0s 471us/sample - loss: 1.1889
# Epoch 50/100
# 100/100 [==============================] - 0s 558us/sample - loss: 1.1886
# Epoch 51/100
# 100/100 [==============================] - 0s 548us/sample - loss: 1.1929
# Epoch 52/100
# 100/100 [==============================] - 0s 596us/sample - loss: 1.1924
# Epoch 53/100
# 100/100 [==============================] - 0s 589us/sample - loss: 1.1864
# Epoch 54/100
# 100/100 [==============================] - 0s 522us/sample - loss: 1.2018
# Epoch 55/100
# 100/100 [==============================] - 0s 444us/sample - loss: 1.1846
# Epoch 56/100
# 100/100 [==============================] - 0s 477us/sample - loss: 1.2063
# Epoch 57/100
# 100/100 [==============================] - ETA: 0s - loss: 1.298 - 0s 432us/sample - loss: 1.1618
# Epoch 58/100
# 100/100 [==============================] - 0s 442us/sample - loss: 1.1980
# Epoch 59/100
# 100/100 [==============================] - 0s 456us/sample - loss: 1.1852
# Epoch 60/100
# 100/100 [==============================] - 0s 472us/sample - loss: 1.1950
# Epoch 61/100
# 100/100 [==============================] - 0s 443us/sample - loss: 1.1978
# Epoch 62/100
# 100/100 [==============================] - 0s 434us/sample - loss: 1.1886
# Epoch 63/100
# 100/100 [==============================] - 0s 471us/sample - loss: 1.1886
# Epoch 64/100
# 100/100 [==============================] - 0s 460us/sample - loss: 1.1886
# Epoch 65/100
# 100/100 [==============================] - 0s 433us/sample - loss: 1.1886
# Epoch 66/100
# 100/100 [==============================] - 0s 454us/sample - loss: 1.1886
# Epoch 67/100
# 100/100 [==============================] - 0s 448us/sample - loss: 1.1886
# Epoch 68/100
# 100/100 [==============================] - 0s 454us/sample - loss: 1.1886
# Epoch 69/100
# 100/100 [==============================] - 0s 432us/sample - loss: 1.1886
# Epoch 70/100
# 100/100 [==============================] - 0s 435us/sample - loss: 1.1886
# Epoch 71/100
# 100/100 [==============================] - 0s 454us/sample - loss: 1.1759
# Epoch 72/100
# 100/100 [==============================] - 0s 468us/sample - loss: 1.1886
# Epoch 73/100
# 100/100 [==============================] - 0s 438us/sample - loss: 1.1886
# Epoch 74/100
# 100/100 [==============================] - 0s 495us/sample - loss: 1.1886
# Epoch 75/100
# 100/100 [==============================] - 0s 501us/sample - loss: 1.1882
# Epoch 76/100
# 100/100 [==============================] - 0s 447us/sample - loss: 1.1886
# Epoch 77/100
# 100/100 [==============================] - 0s 434us/sample - loss: 1.1886
# Epoch 78/100
# 100/100 [==============================] - 0s 444us/sample - loss: 1.1886
# Epoch 79/100
# 100/100 [==============================] - 0s 452us/sample - loss: 1.1886
# Epoch 80/100
# 100/100 [==============================] - 0s 431us/sample - loss: 1.1975
# Epoch 81/100
# 100/100 [==============================] - 0s 479us/sample - loss: 1.1886
# Epoch 82/100
# 100/100 [==============================] - 0s 464us/sample - loss: 1.1886
# Epoch 83/100
# 100/100 [==============================] - 0s 447us/sample - loss: 1.1886
# Epoch 84/100
# 100/100 [==============================] - 0s 465us/sample - loss: 1.1886
# Epoch 85/100
# 100/100 [==============================] - 0s 422us/sample - loss: 1.1963
# Epoch 86/100
# 100/100 [==============================] - 0s 468us/sample - loss: 1.2018
# Epoch 87/100
# 100/100 [==============================] - 0s 472us/sample - loss: 1.1886
# Epoch 88/100
# 100/100 [==============================] - 0s 474us/sample - loss: 1.1886
# Epoch 89/100
# 100/100 [==============================] - 0s 436us/sample - loss: 1.1886
# Epoch 90/100
# 100/100 [==============================] - 0s 486us/sample - loss: 1.1886
# Epoch 91/100
# 100/100 [==============================] - 0s 453us/sample - loss: 1.1886
# Epoch 92/100
# 100/100 [==============================] - 0s 444us/sample - loss: 1.1886
# Epoch 93/100
# 100/100 [==============================] - 0s 497us/sample - loss: 1.1975
# Epoch 94/100
# 100/100 [==============================] - 0s 438us/sample - loss: 1.1886
# Epoch 95/100
# 100/100 [==============================] - 0s 484us/sample - loss: 1.1885
# Epoch 96/100
# 100/100 [==============================] - 0s 473us/sample - loss: 1.1857
# Epoch 97/100
# 100/100 [==============================] - 0s 465us/sample - loss: 1.1807
# Epoch 98/100
# 100/100 [==============================] - 0s 436us/sample - loss: 1.1886
# Epoch 99/100
# 100/100 [==============================] - 0s 442us/sample - loss: 1.1886
# Epoch 100/100
# 100/100 [==============================] - 0s 446us/sample - loss: 1.1886

# %%
loss = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', score)
# Out:
# ('Train loss:', 0.3263232588768005)
